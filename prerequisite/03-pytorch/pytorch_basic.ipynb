# %%
import torch

# %%
# Out:
# Package                     Version
# --------------------------- ---------------
# accelerate                  1.10.1
# aiodns                      3.1.1
# aiohappyeyeballs            2.6.1
# aiohttp                     3.13.4
# aiosignal                   1.4.0
# aiosqlite                   0.22.1
# annotated-doc               0.0.4
# annotated-types             0.7.0
# anthropic                   0.102.0
# anyio                       4.13.0
# appdirs                     1.4.4
# ast_serialize               0.3.0
# async-timeout               4.0.3
# attrs                       23.2.0
# av                          17.0.1
# Babel                       2.10.3
# backtrader                  1.9.78.123
# bandit                      1.9.4
# bcc                         0.29.1
# bcrypt                      3.2.2
# beautifulsoup4              4.12.3
# black                       26.3.1
# blinker                     1.9.0
# Bottleneck                  1.3.5
# ...
